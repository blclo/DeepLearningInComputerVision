# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 128, done.
# remote: Total 128 (delta 0), reused 0 (delta 0), pack-reused 128
# Receiving objects: 100% (128/128), 1.12 MiB | 22.07 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
# %cd stylegan2-ada-pytorch
# Out:
# /content/stylegan2-ada-pytorch

# %%
pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.9/205.9 kB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 61.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: imageio-ffmpeg
#     Found existing installation: imageio-ffmpeg 0.4.8
#     Uninstalling imageio-ffmpeg-0.4.8:
#       Successfully uninstalled imageio-ffmpeg-0.4.8
# ...

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-69cffc96-d5ba-e5cd-d2a5-41414b7af5d1)

# %%
# !pip install torch torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !gdown --id 1aMK0wmYmV5EwZ0FXFhhA4tpYxSUs7T3y -O pretrained/metfaces.pkl
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Access denied with the following error:
#
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1aMK0wmYmV5EwZ0FXFhhA4tpYxSUs7T3y

# %%
# !python generate.py --outdir=out --trunc=1 --seeds=85,265,297,849 --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"...
# ...
# Generating image for seed 85 (0/4) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 265 (1/4) ...
# Generating image for seed 297 (2/4) ...
# Generating image for seed 849 (3/4) ...

# %%
# !python projector.py --outdir=out/aligned_celeb7 --target=aligned_images/align-celeb-7.jpeg --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501: UserWarning: operator() profile_node %106 : int = prim::profile_ivalue(%104)
#  does not have profile information (Triggered internally at ../third_party/nvfuser/csrc/graph_fuser.cpp:104.)
#   return forward_call(*args, **kwargs)
# step    1/1000: dist 0.65 loss 24567.32
# step    2/1000: dist 0.70 loss 27640.68
# step    3/1000: dist 0.66 loss 27166.78
# step    4/1000: dist 0.60 loss 26253.39
# step    5/1000: dist 0.65 loss 24957.26
# step    6/1000: dist 0.61 loss 23352.15
# step    7/1000: dist 0.54 loss 21510.69
# step    8/1000: dist 0.59 loss 19486.86
# step    9/1000: dist 0.61 loss 17341.55
# step   10/1000: dist 0.55 loss 15140.34
# ...

# %%
# !python projector.py --outdir=out/aligned_celeb1 --target=aligned_images/align-celeb-1.jpg --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501: UserWarning: operator() profile_node %106 : int = prim::profile_ivalue(%104)
#  does not have profile information (Triggered internally at ../third_party/nvfuser/csrc/graph_fuser.cpp:104.)
#   return forward_call(*args, **kwargs)
# step    1/1000: dist 0.64 loss 24567.30
# step    2/1000: dist 0.67 loss 27640.64
# step    3/1000: dist 0.65 loss 27166.77
# step    4/1000: dist 0.61 loss 26253.40
# step    5/1000: dist 0.58 loss 24957.20
# step    6/1000: dist 0.67 loss 23352.21
# step    7/1000: dist 0.62 loss 21510.78
# step    8/1000: dist 0.62 loss 19486.90
# step    9/1000: dist 0.59 loss 17341.54
# step   10/1000: dist 0.60 loss 15140.38
# ...

# %%
# !python projector.py --outdir=out/aligned_pieterjan --target=aligned_images/align-pieterjan.jpg --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501: UserWarning: operator() profile_node %106 : int = prim::profile_ivalue(%104)
#  does not have profile information (Triggered internally at ../third_party/nvfuser/csrc/graph_fuser.cpp:104.)
#   return forward_call(*args, **kwargs)
# step    1/1000: dist 0.66 loss 24567.33
# step    2/1000: dist 0.76 loss 27640.74
# step    3/1000: dist 0.70 loss 27166.82
# step    4/1000: dist 0.59 loss 26253.38
# step    5/1000: dist 0.58 loss 24957.19
# step    6/1000: dist 0.71 loss 23352.25
# step    7/1000: dist 0.58 loss 21510.73
# step    8/1000: dist 0.61 loss 19486.88
# step    9/1000: dist 0.61 loss 17341.55
# step   10/1000: dist 0.61 loss 15140.39
# ...

# %%
# !python projector.py --outdir=out/aligned_clau --target=aligned_images/align-clau.jpg --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501: UserWarning: operator() profile_node %106 : int = prim::profile_ivalue(%104)
#  does not have profile information (Triggered internally at ../third_party/nvfuser/csrc/graph_fuser.cpp:104.)
#   return forward_call(*args, **kwargs)
# step    1/1000: dist 0.58 loss 24567.24
# step    2/1000: dist 0.61 loss 27640.59
# step    3/1000: dist 0.61 loss 27166.73
# step    4/1000: dist 0.61 loss 26253.41
# step    5/1000: dist 0.63 loss 24957.24
# step    6/1000: dist 0.60 loss 23352.14
# step    7/1000: dist 0.59 loss 21510.74
# step    8/1000: dist 0.57 loss 19486.84
# step    9/1000: dist 0.54 loss 17341.48
# step   10/1000: dist 0.55 loss 15140.34
# ...

# %%
# !python projector.py --outdir=out --target=aligned_images/align-carol.jpg --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"...
#
# Aborted!

# %%
pip install --upgrade imageio-ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 61.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: imageio-ffmpeg
#     Found existing installation: imageio-ffmpeg 0.4.3
#     Uninstalling imageio-ffmpeg-0.4.3:
#       Successfully uninstalled imageio-ffmpeg-0.4.3
# ...

# %%
# !python style_mixing.py --outdir=out/style-mixing --rows=85,100,75,458,1500 --cols=55,821,1789,293 --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"...
# Generating W vectors...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Generating images...
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating style-mixed images...
# Saving images...
# Saving image grid...

# %%
import torch.nn.functional as F
import torch
import pickle
import dnnlib
import legacy
import os
import re
from typing import List

import click
import PIL.Image

# Load the .npz file
import numpy as np

# Load the .npz file
data_clau = np.load('/content/stylegan2-ada-pytorch/out/aligned_clau/projected_w.npz')
# Load the .npz file
data_carol = np.load('/content/stylegan2-ada-pytorch/out/projected_w.npz')

network_pkl = "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"
device = torch.device('cuda')

# Load the pre-trained generator model
with dnnlib.util.open_url(network_pkl) as f:
      G = legacy.load_network_pkl(f)['G_ema'].to(device) # type: ignore

w1 = data_carol['w']
w1 = torch.from_numpy(w1).to(device)
w2 = data_clau['w']
w2 = torch.from_numpy(w2).to(device)

# Generate the reconstructed images
with torch.no_grad():
    img1 = G.synthesis(w1, noise_mode='const')
    img2 = G.synthesis(w2, noise_mode='const')

num_steps = 10  # Number of interpolation steps
interpolated_images = []
interpolation_level = []
# Perform linear interpolation
for i in range(num_steps):
    alpha = i / (num_steps - 1)  # Interpolation factor between 0 and 1
    interpolation_level.append(alpha)
    w_interp = alpha * w1 + (1 - alpha) * w2
    with torch.no_grad():
        interp_img = G.synthesis(w_interp, noise_mode='const', force_fp32=True)
        interpolated_images.append(interp_img)

# Add the original images to the interpolation sequence
interpolated_images = interpolated_images 
interpolation_level = interpolation_level

# %%
print(interpolation_level)
print(len(interpolated_images))
# Out:
# [0.0, 0.1111111111111111, 0.2222222222222222, 0.3333333333333333, 0.4444444444444444, 0.5555555555555556, 0.6666666666666666, 0.7777777777777778, 0.8888888888888888, 1.0]
# 10

# %%
import matplotlib.pyplot as plt

# Assuming interpolated_images is a list of generated images

# Create a grid to display the images
num_images = len(interpolated_images)
fig, axes = plt.subplots(1, num_images, figsize=(10, 10))

# Iterate over the images and plot them
for i in range(num_images):
    img = interpolated_images[i]
    img = img.squeeze().cpu().numpy()  # Convert the image tensor to a NumPy array
    img = (img + 1) / 2  # Rescale the pixel values from [-1, 1] to [0, 1]
    axes[i].imshow(img.transpose(1, 2, 0))
    axes[i].axis('off')
    # Add a title to the image
    axes[i].set_title(f"{interpolation_level[i]*100:.2f}%", fontsize=8)

plt.tight_layout()
plt.savefig("out/interpolations/clau_to_carol.png")
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
